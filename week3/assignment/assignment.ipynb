# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_theme(style='whitegrid')

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ### Generate 200 samples with 10 features for multiple regression problem with 10 outputs and find the shapes of the feature matrix and the label vector.

# %%
from sklearn.datasets import make_regression, make_classification

# %%
X, y = make_regression(n_samples=200, n_features=10, n_targets=10, random_state=32)

# %%
X.shape , y.shape
# Out:
# ((200, 10), (200, 10))

# %%
pd.DataFrame(X)
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.938058 -0.681415  0.053116 -0.851740  0.289713 -1.787912 -0.201098
# 1    0.740218 -0.399320  0.289023  0.346822  0.512659  0.596708  1.971759
# 2    2.007743 -0.007124 -0.583792  0.387109 -0.063660 -0.310212  0.594403
# 3    1.089226  0.978082  0.331685  0.301408 -0.002755  0.087856  0.630600
# 4   -1.473095 -0.807468 -0.280695  0.932160 -1.159797 -0.795059 -1.032756
# ..        ...       ...       ...       ...       ...       ...       ...
# 195 -1.494453  1.749575  0.357096  0.529147  1.513356  1.258568  1.449171
# 196  0.549679  0.320566 -0.601131 -0.190654  0.631611 -0.230397 -0.485227
# 197 -1.849246 -1.770336 -0.642594  1.524085  0.470398 -0.284954  0.540365
# 198 -0.397221 -0.310783 -1.165282  1.046377  0.169274 -0.836653  0.297333
# 199  0.592471 -1.027090 -0.864580 -0.508619 -1.011863  0.224480  0.142552
#
#             7         8         9
# 0   -1.628303 -0.017489  0.966998
# ...

# %%
pd.DataFrame(y)
# Out:
#               0           1           2           3           4           5  \
# 0   -286.055503  -93.792714 -154.126054 -167.252568 -159.195864  -95.278722
# 1    330.377314  330.487042  337.326414  170.890994  408.181482  186.424592
# 2      5.332198  234.377266  247.124030   46.281334  194.649788   45.659885
# 3    377.370214  272.926464  353.473600  303.020110  414.093100  210.210438
# 4   -139.726789    4.420340 -167.665569   25.293142 -154.556134  -74.488833
# ..          ...         ...         ...         ...         ...         ...
# 195  250.701672  -57.089755  -16.314493  -12.295184   65.059920   63.308046
# 196  -54.075784  -52.186430  -53.595549  -25.379595  -41.988418  -13.986168
# 197 -168.497443  -32.484849 -114.307940  -37.307964 -193.167740 -262.022476
# 198 -178.650432  -59.185143 -143.482209  -75.867693 -160.511549 -117.854005
# 199 -128.744310 -261.904316 -129.001338  -97.425103 -186.609114  -40.869810
#
#               6           7           8           9
# ...

# %%
import matplotlib.pyplot as plt

# Plot the first feature against each of the 10 targets
fig, axes = plt.subplots(2, 5, figsize=(15, 6))
axes = axes.ravel()  # Flatten the 2D grid of axes for easy indexing

for i in range(10):
    axes[i].scatter(X[:, 0], y[:, i], alpha=0.7, label=f"Target {i+1}")
    axes[i].set_title(f"Feature 1 vs Target {i+1}")
    axes[i].set_xlabel("Feature 1")
    axes[i].set_ylabel(f"Target {i+1}")
    axes[i].legend()

plt.tight_layout()
plt.show()

# %%
X, y = make_classification(n_samples=200,n_features=10,n_classes=3,n_informative=3)

# %%
X
# Out:
# array([[ 0.017339  ,  0.51852746,  0.63393739, ..., -0.56251072,
#          1.45615895,  0.06562962],
#        [ 0.60245521, -2.57901871,  1.80689506, ...,  2.87221504,
#          1.57695126,  3.18307402],
#        [-0.54248819,  0.328946  ,  0.22824804, ..., -0.5867209 ,
#         -1.27750282, -1.35287889],
#        ...,
#        [-0.1133813 , -0.06091207, -0.47056407, ...,  0.97421914,
#          1.86516657,  1.87684391],
#        [-0.12499674, -0.72489652,  0.74941371, ..., -0.55854068,
#         -0.07383353, -0.4179175 ],
#        [ 0.04589434, -1.34403653,  0.71729121, ...,  2.28173524,
#          0.78045559,  1.94939298]])
